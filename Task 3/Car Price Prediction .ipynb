# %% [markdown]
# # About the dataset
# <div style="width:100%;text-align: center;">
#     <img align = middle src="https://autohexa.com/wp-content/uploads/2023/04/Bugatti-Chiron-Super-Sport-300-1.jpg" alt="Bugati Chiron 300+" style="height:400px;margin-top:3rem;">
# </div>
#
#
#
# 1) **how does cars price decides whether a customer wants to by that car or not?**
#     * **Affordability:** Customers assess if the car's price aligns with their budget and financial capabilities. If the price is too high, it may be unaffordable and dissuade them from making a purchase.
#     * **Value for Money:** Customers compare the price to the car's features, quality, and overall value proposition. A fair price for the perceived value is more likely to attract buyers.
#     * **Financing Options:** The price affects the availability of financing options. A lower-priced car may offer more favorable financing terms, making it more appealing to customers who rely on loans.
#     * **Resale Value:** Customers consider how the car's price will impact its future resale or trade-in value. A higher resale value can make a car more attractive, as it minimizes the long-term cost of ownership.
#     * **Competition:** The price of a car is compared to similar models from other manufacturers. Customers may choose a car based on its competitive pricing relative to alternatives with similar features and capabilities.
# <hr>
# 2) **What does a customer looks while buying a car?**
#     * **Reliability and Durability:** Customers want a car that is known for reliability and durability. They look for brands and models with a track record of requiring fewer repairs and having a longer lifespan.
#     * **Safety Features:** Safety is a top priority. Customers are drawn to cars with advanced safety features such as airbags, anti-lock brakes, collision avoidance systems, and high crash-test ratings.
#     * **Fuel Efficiency:** With rising fuel costs and environmental concerns, customers are attracted to cars that offer good fuel efficiency. Vehicles with hybrid or electric options are increasingly popular for their eco-friendliness.
#     * **Technology and Connectivity:** Modern customers expect advanced technology and connectivity features. Cars with intuitive infotainment systems, smartphone integration, and driver assistance technology (e.g., adaptive cruise control, lane-keeping assist) are highly attractive.
#     * **Comfort and Interior Quality:** Interior comfort, quality of materials, and ergonomic design matter to customers. A well-designed, comfortable interior with spacious seating and user-friendly controls can be a significant selling point.
# <hr>
#
# * The following are the column description of the dataset
#     * **Car_ID** :- Unique id of each observation (Interger)
#     * **Symboling** :- Its assigned insurance risk rating, A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.(Categorical)
#     * **carCompany** :- Name of car company (Categorical)
#     * **fueltype** :- Car fuel type i.e gas or diesel (Categorical)
#     * **aspiration** :-Aspiration used in a car (Categorical)
#     * **doornumber** :-Number of doors in a car (Categorical)
#     * **carbody** :-body of car (Categorical)
#     * **drivewheel** :-type of drive wheel (Categorical)
#     * **enginelocation** :-Location of car engine (Categorical)
#     * **wheelbase** :-Weelbase of car (Numeric)
#     * **carlength** :-Length of car (Numeric)
#     * **carwidth** :-Width of car (Numeric)
#     * **carheight** :-height of car (Numeric)
#     * **curbweight** :-The weight of a car without occupants or baggage. (Numeric)
#     * **enginetype** :-Type of engine. (Categorical)
#     * **cylindernumber** :- cylinder placed in the car (Categorical)
#     * **enginesize** :-Size of car (Numeric)
#     * **fuelsystem** :-Fuel system of car (Categorical)
#     * **boreratio** :-Boreratio of car (Numeric)
#     * **stroke** :-Stroke or volume inside the engine (Numeric)
#     * **compressionratio** :-compression ratio of car (Numeric)
#     * **horsepower** :-Horsepower (Numeric)
#     * **peakrpm** :-car peak rpm (Numeric)
#     * **citympg** :-Mileage in city (Numeric)
#     * **highwaympg** :-Mileage on highway (Numeric)
#     * **price(Dependent variable)** :-Price of car (Numeric)

# %% [markdown]
# # Importing the library and dataset

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('CarPrice_Assignment.csv')

# %% [markdown]
# # Exploratory data Analysis

# %%
# How does the data look like?
df.sample(5)
# Out:
#      car_ID  symboling            CarName fueltype aspiration doornumber  \
# 48       49          0          jaguar xf      gas        std       four
# 128     129          3     porsche boxter      gas        std        two
# 169     170          2     toyota starlet      gas        std        two
# 43       44          0         isuzu MU-X      gas        std       four
# 77       78          2  mitsubishi lancer      gas        std        two
#
#          carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 48         sedan        rwd          front      113.0  ...         258
# 128  convertible        rwd           rear       89.5  ...         194
# 169    hatchback        rwd          front       98.4  ...         146
# 43         sedan        rwd          front       94.3  ...         111
# 77     hatchback        fwd          front       93.7  ...          92
#
#      fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 48         mpfi       3.63    4.17              8.1        176     4750
# 128        mpfi       3.74    2.90              9.5        207     5900
# 169        mpfi       3.62    3.50              9.3        116     4800
# 43         2bbl       3.31    3.23              8.5         78     4800
# 77         2bbl       2.97    3.23              9.4         68     5500
#
#     citympg  highwaympg    price
# 48       15          19  35550.0
# 128      17          25  37028.0
# 169      24          30   9989.0
# 43       24          29   6785.0
# 77       31          38   6189.0
#
# [5 rows x 26 columns]

# %%
# what is the shape of the dataset ?
df.shape
# Out:
# (205, 26)

# %%
# what are the data types of the dataset?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
# how does the data look like mathematically?
df.describe(include = 'all')
# Out:
#             car_ID   symboling        CarName fueltype aspiration doornumber  \
# count   205.000000  205.000000            205      205        205        205
# unique         NaN         NaN            147        2          2          2
# top            NaN         NaN  toyota corona      gas        std       four
# freq           NaN         NaN              6      185        168        115
# mean    103.000000    0.834146            NaN      NaN        NaN        NaN
# std      59.322565    1.245307            NaN      NaN        NaN        NaN
# min       1.000000   -2.000000            NaN      NaN        NaN        NaN
# 25%      52.000000    0.000000            NaN      NaN        NaN        NaN
# 50%     103.000000    1.000000            NaN      NaN        NaN        NaN
# 75%     154.000000    2.000000            NaN      NaN        NaN        NaN
# max     205.000000    3.000000            NaN      NaN        NaN        NaN
#
#        carbody drivewheel enginelocation   wheelbase  ...  enginesize  \
# count      205        205            205  205.000000  ...  205.000000
# unique       5          3              2         NaN  ...         NaN
# top      sedan        fwd          front         NaN  ...         NaN
# freq        96        120            202         NaN  ...         NaN
# mean       NaN        NaN            NaN   98.756585  ...  126.907317
# std        NaN        NaN            NaN    6.021776  ...   41.642693
# min        NaN        NaN            NaN   86.600000  ...   61.000000
# 25%        NaN        NaN            NaN   94.500000  ...   97.000000
# 50%        NaN        NaN            NaN   97.000000  ...  120.000000
# 75%        NaN        NaN            NaN  102.400000  ...  141.000000
# max        NaN        NaN            NaN  120.900000  ...  326.000000
#
#         fuelsystem   boreratio      stroke compressionratio  horsepower  \
# count          205  205.000000  205.000000       205.000000  205.000000
# unique           8         NaN         NaN              NaN         NaN
# top           mpfi         NaN         NaN              NaN         NaN
# freq            94         NaN         NaN              NaN         NaN
# mean           NaN    3.329756    3.255415        10.142537  104.117073
# std            NaN    0.270844    0.313597         3.972040   39.544167
# min            NaN    2.540000    2.070000         7.000000   48.000000
# 25%            NaN    3.150000    3.110000         8.600000   70.000000
# 50%            NaN    3.310000    3.290000         9.000000   95.000000
# 75%            NaN    3.580000    3.410000         9.400000  116.000000
# max            NaN    3.940000    4.170000        23.000000  288.000000
#
#             peakrpm     citympg  highwaympg         price
# count    205.000000  205.000000  205.000000    205.000000
# unique          NaN         NaN         NaN           NaN
# top             NaN         NaN         NaN           NaN
# freq            NaN         NaN         NaN           NaN
# mean    5125.121951   25.219512   30.751220  13276.710571
# std      476.985643    6.542142    6.886443   7988.852332
# min     4150.000000   13.000000   16.000000   5118.000000
# 25%     4800.000000   19.000000   25.000000   7788.000000
# 50%     5200.000000   24.000000   30.000000  10295.000000
# 75%     5500.000000   30.000000   34.000000  16503.000000
# max     6600.000000   49.000000   54.000000  45400.000000
#
# [11 rows x 26 columns]

# %%
# Check for null values
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# correlation between the columns
fig, ax = plt.subplots(figsize = (20,10))
sns.heatmap(df.drop(['car_ID'],axis = 1).corr(numeric_only = True),annot = True) #dropping the car_ID column and then making the correlation matrix
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2><p style = 'background-color: #FFC0CB'>NOTE:</p></h2>
# <h3><p style ='color :#FF69B4'>Conclusion for Exploratory Data analysis</p></h3>
# <ul>
#     <li>data contains 20 rows and 26 columns</li>
#     <li>16 Numeric column and 10 categorical column are present</li>
#     <li>toyota corona,gas,std,four,sedan,fwd,four,ohc,mpfi and front has the most number of appearance/frequency in categorical column</li>
#     <li>Contains neither null values or duplicate values</li>
#     <li>strong correlation between columns such as wheelbase,carlength,carwidth,carheight,curbweight,enginesize,boreratio,price,horsepower,citympg,highwaympg</li>
# </ul>

# %% [markdown]
# ### Data preprocessing

# %%
del df['car_ID']
# since not relation table is present from the dataset hence car_id is being deleted

# %%
for i in df.columns:
    print(i)
    print(df[i].unique())
    print(df[i].nunique())
    print('-'*50)
# Out:
# symboling
# [ 3  1  2  0 -1 -2]
# 6
# --------------------------------------------------
# CarName
# ['alfa-romero giulia' 'alfa-romero stelvio' 'alfa-romero Quadrifoglio'
#  'audi 100 ls' 'audi 100ls' 'audi fox' 'audi 5000' 'audi 4000'
#  'audi 5000s (diesel)' 'bmw 320i' 'bmw x1' 'bmw x3' 'bmw z4' 'bmw x4'
#  'bmw x5' 'chevrolet impala' 'chevrolet monte carlo' 'chevrolet vega 2300'
#  'dodge rampage' 'dodge challenger se' 'dodge d200' 'dodge monaco (sw)'
#  'dodge colt hardtop' 'dodge colt (sw)' 'dodge coronet custom'
#  'dodge dart custom' 'dodge coronet custom (sw)' 'honda civic'
#  'honda civic cvcc' 'honda accord cvcc' 'honda accord lx'
#  'honda civic 1500 gl' 'honda accord' 'honda civic 1300' 'honda prelude'
#  'honda civic (auto)' 'isuzu MU-X' 'isuzu D-Max ' 'isuzu D-Max V-Cross'
#  'jaguar xj' 'jaguar xf' 'jaguar xk' 'maxda rx3' 'maxda glc deluxe'
#  'mazda rx2 coupe' 'mazda rx-4' 'mazda glc deluxe' 'mazda 626' 'mazda glc'
#  'mazda rx-7 gs' 'mazda glc 4' 'mazda glc custom l' 'mazda glc custom'
#  'buick electra 225 custom' 'buick century luxus (sw)' 'buick century'
#  'buick skyhawk' 'buick opel isuzu deluxe' 'buick skylark'
#  'buick century special' 'buick regal sport coupe (turbo)'
#  'mercury cougar' 'mitsubishi mirage' 'mitsubishi lancer'
#  'mitsubishi outlander' 'mitsubishi g4' 'mitsubishi mirage g4'
#  'mitsubishi montero' 'mitsubishi pajero' 'Nissan versa' 'nissan gt-r'
#  'nissan rogue' 'nissan latio' 'nissan titan' 'nissan leaf' 'nissan juke'
#  'nissan note' 'nissan clipper' 'nissan nv200' 'nissan dayz' 'nissan fuga'
#  'nissan otti' 'nissan teana' 'nissan kicks' 'peugeot 504' 'peugeot 304'
#  'peugeot 504 (sw)' 'peugeot 604sl' 'peugeot 505s turbo diesel'
#  'plymouth fury iii' 'plymouth cricket' 'plymouth satellite custom (sw)'
#  'plymouth fury gran sedan' 'plymouth valiant' 'plymouth duster'
#  'porsche macan' 'porcshce panamera' 'porsche cayenne' 'porsche boxter'
#  'renault 12tl' 'renault 5 gtl' 'saab 99e' 'saab 99le' 'saab 99gle'
#  'subaru' 'subaru dl' 'subaru brz' 'subaru baja' 'subaru r1' 'subaru r2'
#  'subaru trezia' 'subaru tribeca' 'toyota corona mark ii' 'toyota corona'
#  'toyota corolla 1200' 'toyota corona hardtop' 'toyota corolla 1600 (sw)'
#  'toyota carina' 'toyota mark ii' 'toyota corolla'
#  'toyota corolla liftback' 'toyota celica gt liftback'
#  'toyota corolla tercel' 'toyota corona liftback' 'toyota starlet'
#  'toyota tercel' 'toyota cressida' 'toyota celica gt' 'toyouta tercel'
#  'vokswagen rabbit' 'volkswagen 1131 deluxe sedan' 'volkswagen model 111'
#  'volkswagen type 3' 'volkswagen 411 (sw)' 'volkswagen super beetle'
#  'volkswagen dasher' 'vw dasher' 'vw rabbit' 'volkswagen rabbit'
#  'volkswagen rabbit custom' 'volvo 145e (sw)' 'volvo 144ea' 'volvo 244dl'
#  'volvo 245' 'volvo 264gl' 'volvo diesel' 'volvo 246']
# 147
# --------------------------------------------------
# fueltype
# ['gas' 'diesel']
# 2
# --------------------------------------------------
# aspiration
# ['std' 'turbo']
# 2
# --------------------------------------------------
# doornumber
# ['two' 'four']
# 2
# --------------------------------------------------
# carbody
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# 5
# --------------------------------------------------
# drivewheel
# ['rwd' 'fwd' '4wd']
# 3
# --------------------------------------------------
# enginelocation
# ['front' 'rear']
# 2
# --------------------------------------------------
# wheelbase
# [ 88.6  94.5  99.8  99.4 105.8  99.5 101.2 103.5 110.   88.4  93.7 103.3
#   95.9  86.6  96.5  94.3  96.  113.  102.   93.1  95.3  98.8 104.9 106.7
#  115.6  96.6 120.9 112.  102.7  93.   96.3  95.1  97.2 100.4  91.3  99.2
#  107.9 114.2 108.   89.5  98.4  96.1  99.1  93.3  97.   96.9  95.7 102.4
#  102.9 104.5  97.3 104.3 109.1]
# 53
# --------------------------------------------------
# carlength
# [168.8 171.2 176.6 177.3 192.7 178.2 176.8 189.  193.8 197.  141.1 155.9
#  158.8 157.3 174.6 173.2 144.6 150.  163.4 157.1 167.5 175.4 169.1 170.7
#  172.6 199.6 191.7 159.1 166.8 169.  177.8 175.  190.9 187.5 202.6 180.3
#  208.1 199.2 178.4 173.  172.4 165.3 170.2 165.6 162.4 173.4 181.7 184.6
#  178.5 186.7 198.9 167.3 168.9 175.7 181.5 186.6 156.9 157.9 172.  173.5
#  173.6 158.7 169.7 166.3 168.7 176.2 175.6 183.5 187.8 171.7 159.3 165.7
#  180.2 183.1 188.8]
# 75
# --------------------------------------------------
# carwidth
# [64.1 65.5 66.2 66.4 66.3 71.4 67.9 64.8 66.9 70.9 60.3 63.6 63.8 64.6
#  63.9 64.  65.2 62.5 66.  61.8 69.6 70.6 64.2 65.7 66.5 66.1 70.3 71.7
#  70.5 72.  68.  64.4 65.4 68.4 68.3 65.  72.3 66.6 63.4 65.6 67.7 67.2
#  68.9 68.8]
# 44
# --------------------------------------------------
# carheight
# [48.8 52.4 54.3 53.1 55.7 55.9 52.  53.7 56.3 53.2 50.8 50.6 59.8 50.2
#  52.6 54.5 58.3 53.3 54.1 51.  53.5 51.4 52.8 47.8 49.6 55.5 54.4 56.5
#  58.7 54.9 56.7 55.4 54.8 49.4 51.6 54.7 55.1 56.1 49.7 56.  50.5 55.2
#  52.5 53.  59.1 53.9 55.6 56.2 57.5]
# 49
# --------------------------------------------------
# curbweight
# [2548 2823 2337 2824 2507 2844 2954 3086 3053 2395 2710 2765 3055 3230
#  3380 3505 1488 1874 1909 1876 2128 1967 1989 2191 2535 2811 1713 1819
#  1837 1940 1956 2010 2024 2236 2289 2304 2372 2465 2293 2734 4066 3950
#  1890 1900 1905 1945 1950 2380 2385 2500 2410 2443 2425 2670 2700 3515
#  3750 3495 3770 3740 3685 3900 3715 2910 1918 1944 2004 2145 2370 2328
#  2833 2921 2926 2365 2405 2403 1889 2017 1938 1951 2028 1971 2037 2008
#  2324 2302 3095 3296 3060 3071 3139 3020 3197 3430 3075 3252 3285 3485
#  3130 2818 2778 2756 2800 3366 2579 2460 2658 2695 2707 2758 2808 2847
#  2050 2120 2240 2190 2340 2510 2290 2455 2420 2650 1985 2040 2015 2280
#  3110 2081 2109 2275 2094 2122 2140 2169 2204 2265 2300 2540 2536 2551
#  2679 2714 2975 2326 2480 2414 2458 2976 3016 3131 3151 2261 2209 2264
#  2212 2319 2254 2221 2661 2563 2912 3034 2935 3042 3045 3157 2952 3049
#  3012 3217 3062]
# 171
# --------------------------------------------------
# enginetype
# ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# 7
# --------------------------------------------------
# cylindernumber
# ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
# 7
# --------------------------------------------------
# enginesize
# [130 152 109 136 131 108 164 209  61  90  98 122 156  92  79 110 111 119
#  258 326  91  70  80 140 134 183 234 308 304  97 103 120 181 151 194 203
#  132 121 146 171 161 141 173 145]
# 44
# --------------------------------------------------
# fuelsystem
# ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']
# 8
# --------------------------------------------------
# boreratio
# [3.47 2.68 3.19 3.13 3.5  3.31 3.62 2.91 3.03 2.97 3.34 3.6  2.92 3.15
#  3.43 3.63 3.54 3.08 3.33 3.39 3.76 3.58 3.46 3.8  3.78 3.17 3.35 3.59
#  2.99 3.7  3.61 3.94 3.74 2.54 3.05 3.27 3.24 3.01]
# 38
# --------------------------------------------------
# stroke
# [2.68  3.47  3.4   2.8   3.19  3.39  3.03  3.11  3.23  3.46  3.9   3.41
#  3.07  3.58  4.17  2.76  3.15  3.255 3.16  3.64  3.1   3.35  3.12  3.86
#  3.29  3.27  3.52  2.19  3.21  2.9   2.07  2.36  2.64  3.08  3.5   3.54
#  2.87 ]
# 37
# --------------------------------------------------
# compressionratio
# [ 9.   10.    8.    8.5   8.3   7.    8.8   9.5   9.6   9.41  9.4   7.6
#   9.2  10.1   9.1   8.1  11.5   8.6  22.7  22.   21.5   7.5  21.9   7.8
#   8.4  21.    8.7   9.31  9.3   7.7  22.5  23.  ]
# 32
# --------------------------------------------------
# horsepower
# [111 154 102 115 110 140 160 101 121 182  48  70  68  88 145  58  76  60
#   86 100  78  90 176 262 135  84  64 120  72 123 155 184 175 116  69  55
#   97 152 200  95 142 143 207 288  73  82  94  62  56 112  92 161 156  52
#   85 114 162 134 106]
# 59
# --------------------------------------------------
# peakrpm
# [5000 5500 5800 4250 5400 5100 4800 6000 4750 4650 4200 4350 4500 5200
#  4150 5600 5900 5750 5250 4900 4400 6600 5300]
# 23
# --------------------------------------------------
# citympg
# [21 19 24 18 17 16 23 20 15 47 38 37 31 49 30 27 25 13 26 36 22 14 45 28
#  32 35 34 29 33]
# 29
# --------------------------------------------------
# highwaympg
# [27 26 30 22 25 20 29 28 53 43 41 38 24 54 42 34 33 31 19 17 23 32 39 18
#  16 37 50 36 47 46]
# 30
# --------------------------------------------------
# price
# [13495.    16500.    13950.    17450.    15250.    17710.    18920.
#  23875.    17859.167 16430.    16925.    20970.    21105.    24565.
#  30760.    41315.    36880.     5151.     6295.     6575.     5572.
#   6377.     7957.     6229.     6692.     7609.     8558.     8921.
#  12964.     6479.     6855.     5399.     6529.     7129.     7295.
#   7895.     9095.     8845.    10295.    12945.    10345.     6785.
#   8916.5   11048.    32250.    35550.    36000.     5195.     6095.
#   6795.     6695.     7395.    10945.    11845.    13645.    15645.
#   8495.    10595.    10245.    10795.    11245.    18280.    18344.
#  25552.    28248.    28176.    31600.    34184.    35056.    40960.
#  45400.    16503.     5389.     6189.     6669.     7689.     9959.
#   8499.    12629.    14869.    14489.     6989.     8189.     9279.
#   5499.     7099.     6649.     6849.     7349.     7299.     7799.
#   7499.     7999.     8249.     8949.     9549.    13499.    14399.
#  17199.    19699.    18399.    11900.    13200.    12440.    13860.
#  15580.    16900.    16695.    17075.    16630.    17950.    18150.
#  12764.    22018.    32528.    34028.    37028.    31400.5    9295.
#   9895.    11850.    12170.    15040.    15510.    18620.     5118.
#   7053.     7603.     7126.     7775.     9960.     9233.    11259.
#   7463.    10198.     8013.    11694.     5348.     6338.     6488.
#   6918.     7898.     8778.     6938.     7198.     7788.     7738.
#   8358.     9258.     8058.     8238.     9298.     9538.     8449.
#   9639.     9989.    11199.    11549.    17669.     8948.    10698.
#   9988.    10898.    11248.    16558.    15998.    15690.    15750.
#   7975.     7995.     8195.     9495.     9995.    11595.     9980.
#  13295.    13845.    12290.    12940.    13415.    15985.    16515.
#  18420.    18950.    16845.    19045.    21485.    22470.    22625.   ]
# 189
# --------------------------------------------------

# %%
dct = {'four': 4 , 'six': 6, 'five': 5 , 'three': 3, 'twelve':12, 'two':2, 'eight':8}
new = []
for i in df['cylindernumber']:
    if (i) in dct:
        new.append(dct[i])
df['cylindernumber'] = new

# %%
# creating different columns for different cars
brand = []
model = []
for i in df.values:
    if len(i[1].split(' ')) >= 2:
        brand.append(i[1].split(' ')[0].lower())
        model.append(' '.join(i[1].split(' ')[1:]))
    else:
        brand.append(i[1])
        model.append('Missing')
        
df['Brand'] = brand
df['Model'] =  model
del df['CarName']

# %%
df.head()
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  boreratio  stroke  \
# 0          front       88.6      168.8      64.1  ...       3.47    2.68
# 1          front       88.6      168.8      64.1  ...       3.47    2.68
# 2          front       94.5      171.2      65.5  ...       2.68    3.47
# 3          front       99.8      176.6      66.2  ...       3.19    3.40
# 4          front       99.4      176.6      66.4  ...       3.19    3.40
#
#   compressionratio  horsepower  peakrpm citympg  highwaympg    price  \
# 0              9.0         111     5000      21          27  13495.0
# 1              9.0         111     5000      21          27  16500.0
# 2              9.0         154     5000      19          26  16500.0
# 3             10.0         102     5500      24          30  13950.0
# 4              8.0         115     5500      18          22  17450.0
#
#          Brand         Model
# 0  alfa-romero        giulia
# 1  alfa-romero       stelvio
# 2  alfa-romero  Quadrifoglio
# 3         audi        100 ls
# 4         audi         100ls
#
# [5 rows x 26 columns]

# %% [markdown]
# ### data contains some typo error
# * alfa-romero = alfa-romeo
# * volkswagen = vokswagen = vw
# * mazda = maxda
# * toyota = toyota
# * porsche = porcshce

# %%
df['Brand'] = df['Brand'].replace({'alfa-romero':'alfa-romeo','maxda': 'mazda', 'porcshce': 'porsche', 'toyouta': 'toyota','vokswagen': 'volkswagen', 'vw': 'volkswagen'})
df['price'] = df['price'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   fueltype          205 non-null    object
#  2   aspiration        205 non-null    object
#  3   doornumber        205 non-null    object
#  4   carbody           205 non-null    object
#  5   drivewheel        205 non-null    object
#  6   enginelocation    205 non-null    object
#  7   wheelbase         205 non-null    float64
#  8   carlength         205 non-null    float64
#  9   carwidth          205 non-null    float64
#  10  carheight         205 non-null    float64
#  11  curbweight        205 non-null    int64
#  12  enginetype        205 non-null    object
#  13  cylindernumber    205 non-null    int64
#  14  enginesize        205 non-null    int64
#  15  fuelsystem        205 non-null    object
#  16  boreratio         205 non-null    float64
#  17  stroke            205 non-null    float64
#  18  compressionratio  205 non-null    float64
#  19  horsepower        205 non-null    int64
#  20  peakrpm           205 non-null    int64
#  21  citympg           205 non-null    int64
#  22  highwaympg        205 non-null    int64
#  23  price             205 non-null    int64
#  24  Brand             205 non-null    object
#  25  Model             205 non-null    object
# dtypes: float64(7), int64(9), object(10)
# memory usage: 41.8+ KB

# %%
df = df.reindex(columns = ['Brand','Model','fueltype','aspiration','doornumber','carbody','drivewheel','enginelocation','enginetype',
                      'fuelsystem','symboling','wheelbase','carlength','carwidth','carheight','curbweight','cylindernumber',
                      'enginesize','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg','price'])

# %% [markdown]
# ## Univariate Analysis
# ### Categorical data

# %%
fig,ax = plt.subplots(figsize = (8,8))
plt.pie(x = df['Brand'].value_counts(),labels = df['Brand'].value_counts().index,autopct = '%1.2f%%')
plt.show()

# %%
def barPlot(col,fig):
    plt.subplot(5,2,fig)
    plt.bar(x = df[col].unique(),height =df[col].value_counts())
    plt.xticks(rotation = 90) 
    plt.title(col.title())
    plt.xlabel(col.capitalize())

plt.figure(figsize =(25,35))
barPlot('Brand',1)
barPlot('Model',2)
barPlot('fueltype',3)
barPlot('aspiration',4)
barPlot('doornumber',5)
barPlot('carbody',6)
barPlot('drivewheel',7)
barPlot('enginelocation',8)
barPlot('enginetype',9)
barPlot('fuelsystem',10)
plt.tight_layout()
plt.show()

# %%
def boxPlot(col,fig):
    plt.subplot(5,3,fig)
    plt.boxplot(df[col].value_counts())
    plt.title(col.capitalize())
    plt.xlabel(col.capitalize())

# %%
# univariate analysis on individual data 
plt.figure(figsize =(10,15))
boxPlot('Brand',1)                   # outlier present
boxPlot('Model',2)                   # outlier present
boxPlot('fueltype',3)
boxPlot('aspiration',4)
boxPlot('doornumber',5)
boxPlot('carbody',6)
boxPlot('drivewheel',7)
boxPlot('enginelocation',8)
boxPlot('enginetype',9)              # outlier present
boxPlot('fuelsystem',10)             # outlier present
plt.tight_layout()
plt.show()

# %%
df['enginetype'].value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %% [markdown]
# ### Numerical data univariate analysis

# %%
def barGraph(colName,fig):
    plt.subplot(6,3,fig)
    plt.bar(x = df[colName].unique() , height = df[colName].value_counts())
    plt.xticks(rotation = 90) 
    plt.title(colName.title())
    plt.xlabel(colName)
    

plt.figure(figsize = (15,18))
barGraph('symboling',1)
barGraph('wheelbase',2)
barGraph('carlength',3)
barGraph('carwidth',4)
barGraph('carheight',5)
barGraph('curbweight',6)
barGraph('cylindernumber',7)
barGraph('enginesize',8)
barGraph('boreratio',9)
barGraph('stroke',10)
barGraph('compressionratio',11)
barGraph('horsepower',12)
barGraph('citympg',13)
barGraph('highwaympg',14)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (15,18))
boxPlot('symboling',1)
boxPlot('wheelbase',2)             # Outlier may be present
boxPlot('carlength',3)             # Outlier may be present
boxPlot('carwidth',4)              # Outlier may be present
boxPlot('carheight',5)             # Outlier may be present
boxPlot('curbweight',6)            # Outlier may be present
boxPlot('cylindernumber',7)        # Outlier may be present
boxPlot('enginesize',8)            # Outlier may be present
boxPlot('boreratio',9)             # Outlier may be present
boxPlot('stroke',10)               # Outlier may be present
boxPlot('compressionratio',11)     # Outlier may be present
boxPlot('horsepower',12)           # Outlier may be present
boxPlot('citympg',13)              # Outlier may be present
boxPlot('highwaympg',14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
def scatterPlot(col,fig):
    plt.subplot(6,2,fig)
    plt.scatter(df[col],df['price'])
    plt.title(col.capitalize() + ' vs Price' )
    plt.ylabel('Price')
    plt.xlabel(col.capitalize())

# %%
plt.figure(figsize = (20, 30))
scatterPlot('wheelbase',1)
scatterPlot('carlength',2)
scatterPlot('carwidth',3)
scatterPlot('carheight',4)
scatterPlot('curbweight',5)
scatterPlot('boreratio',6)
scatterPlot('stroke',7)
scatterPlot('horsepower',8)
scatterPlot('peakrpm',9)
scatterPlot('citympg',10)
scatterPlot('highwaympg',11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df[['wheelbase', 'carlength', 'carwidth','curbweight','cylindernumber','enginesize', 'boreratio', 'horsepower','price']])

# %% [markdown]
# <h2><p style = 'background-color: #FFC0CB'>NOTE:</p></h2>
# <p style = 'color : ##4169E1;background-color: #FFC0CB'>After visual analysis found that outlier are present in the dataset</p>
# <p style = 'color : ##4169E1;background-color: #FFC0CB'>The following are the list of columns which contains outlier</p>
# <ul>
# <li>wheelbase</li>
# <li>carlength</li>
# <li>carwidth</li>
# <li>carheight</li>
# <li>curbweight</li>
# <li>boreratio</li>
# <li>stroke</li>
# <li>horsepower</li>
# <li>peakrpm</li>
# <li>citympg</li>
# <li>highwaympg</li>
# <li>Brand</li>
# <li>Model</li>
# <li>enginetype</li>
# <li>fuelsystem</li>
#
# </ul>

# %%
# Outliers in a particular column
upper_limit = df['citympg'].mean() + 3*df['citympg'].std()
lower_limit = df['citympg'].mean() - 3*df['citympg'].std()
df[(df['citympg'] > upper_limit) | (df['citympg'] < lower_limit)]
# Out:
#         Brand   Model fueltype aspiration doornumber    carbody drivewheel  \
# 18  chevrolet  impala      gas        std        two  hatchback        fwd
# 30      honda   civic      gas        std        two  hatchback        fwd
# 90     nissan    gt-r   diesel        std        two      sedan        fwd
#
#    enginelocation enginetype fuelsystem  ...  cylindernumber  enginesize  \
# 18          front          l       2bbl  ...               3          61
# 30          front        ohc       1bbl  ...               4          92
# 90          front        ohc        idi  ...               4         103
#
#     boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 18       2.91    3.03               9.5          48     5100       47
# 30       2.91    3.41               9.6          58     4800       49
# 90       2.99    3.47              21.9          55     4800       45
#
#     highwaympg  price
# 18          53   5151
# 30          54   6479
# 90          50   7099
#
# [3 rows x 26 columns]

# %%
# number of outliers in each column
num = ['highwaympg','citympg','peakrpm','horsepower',
       'stroke','boreratio','curbweight','carheight',
       'carwidth','carlength','wheelbase']

for col in num:
    upper_limit = df[col].mean() + 3 * df[col].std()
    lower_limit = df[col].mean() - 3 * df[col].std()
    df[col] = np.where(df[col] > upper_limit,
                                upper_limit,
                                np.where(df[col] < lower_limit,
                                         lower_limit,
                                         df[col]))

# %%
upper_limit = df['citympg'].mean() + 3*df['citympg'].std()
lower_limit = df['citympg'].mean() - 3*df['citympg'].std()
df[(df['citympg'] > upper_limit) | (df['citympg'] < lower_limit)]
# Out:
#         Brand   Model fueltype aspiration doornumber    carbody drivewheel  \
# 18  chevrolet  impala      gas        std        two  hatchback        fwd
# 30      honda   civic      gas        std        two  hatchback        fwd
# 90     nissan    gt-r   diesel        std        two      sedan        fwd
#
#    enginelocation enginetype fuelsystem  ...  cylindernumber  enginesize  \
# 18          front          l       2bbl  ...               3          61
# 30          front        ohc       1bbl  ...               4          92
# 90          front        ohc        idi  ...               4         103
#
#     boreratio  stroke  compressionratio  horsepower  peakrpm    citympg  \
# 18       2.91    3.03               9.5        48.0   5100.0  44.845937
# 30       2.91    3.41               9.6        58.0   4800.0  44.845937
# 90       2.99    3.47              21.9        55.0   4800.0  44.845937
#
#     highwaympg  price
# 18   51.410549   5151
# 30   51.410549   6479
# 90   50.000000   7099
#
# [3 rows x 26 columns]

# %% [markdown]
# ### Lets divide the data into 3 types
# 1. low budget
# 2. medium budget
# 3. High budget

# %%
# df.loc[ df['price'] <= 20000, 'priceCategory'] = 0
# df.loc[(df['price'] > 20000) & (df['price'] <= 40000), 'priceCategory'] = 1
# df.loc[ df['price'] > 40000, 'priceCategory'] = 2
# df["priceCategory"] = df["priceCategory"].astype(int)

# %%
df
# Out:
#           Brand         Model fueltype aspiration doornumber      carbody  \
# 0    alfa-romeo        giulia      gas        std        two  convertible
# 1    alfa-romeo       stelvio      gas        std        two  convertible
# 2    alfa-romeo  Quadrifoglio      gas        std        two    hatchback
# 3          audi        100 ls      gas        std       four        sedan
# 4          audi         100ls      gas        std       four        sedan
# ..          ...           ...      ...        ...        ...          ...
# 200       volvo     145e (sw)      gas        std       four        sedan
# 201       volvo         144ea      gas      turbo       four        sedan
# 202       volvo         244dl      gas        std       four        sedan
# 203       volvo           246   diesel      turbo       four        sedan
# 204       volvo         264gl      gas      turbo       four        sedan
#
#     drivewheel enginelocation enginetype fuelsystem  ...  cylindernumber  \
# 0          rwd          front       dohc       mpfi  ...               4
# 1          rwd          front       dohc       mpfi  ...               4
# 2          rwd          front       ohcv       mpfi  ...               6
# 3          fwd          front        ohc       mpfi  ...               4
# 4          4wd          front        ohc       mpfi  ...               5
# ..         ...            ...        ...        ...  ...             ...
# 200        rwd          front        ohc       mpfi  ...               4
# 201        rwd          front        ohc       mpfi  ...               4
# 202        rwd          front       ohcv       mpfi  ...               6
# 203        rwd          front        ohc        idi  ...               6
# 204        rwd          front        ohc       mpfi  ...               4
#
#      enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0           130       3.47    2.68               9.0       111.0   5000.0
# 1           130       3.47    2.68               9.0       111.0   5000.0
# 2           152       2.68    3.47               9.0       154.0   5000.0
# 3           109       3.19    3.40              10.0       102.0   5500.0
# 4           136       3.19    3.40               8.0       115.0   5500.0
# ..          ...        ...     ...               ...         ...      ...
# 200         141       3.78    3.15               9.5       114.0   5400.0
# 201         141       3.78    3.15               8.7       160.0   5300.0
# 202         173       3.58    2.87               8.8       134.0   5500.0
# 203         145       3.01    3.40              23.0       106.0   4800.0
# 204         141       3.78    3.15               9.5       114.0   5400.0
#
#      citympg  highwaympg  price
# 0       21.0        27.0  13495
# 1       21.0        27.0  16500
# 2       19.0        26.0  16500
# 3       24.0        30.0  13950
# 4       18.0        22.0  17450
# ..       ...         ...    ...
# 200     23.0        28.0  16845
# 201     19.0        25.0  19045
# 202     18.0        23.0  21485
# 203     26.0        27.0  22470
# 204     19.0        25.0  22625
#
# [205 rows x 26 columns]

# %%
# del df['price']
del df['Brand']
del df['Model']
del df['stroke']
del df['compressionratio']
del df['peakrpm']
del df['carheight']
del df['symboling']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.metrics import confusion_matrix,classification_report

# %%
feature_columns = df.drop('price', axis=1)
target_column='price'
x=feature_columns
y=df[target_column]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_36739/3743661861.py in <module>
#       1 model=LinearRegression()
# ----> 2 model.fit(x_train,y_train)
#
# ~/.local/lib/python3.10/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# ~/.local/lib/python3.10/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1104         )
#    1105
# -> 1106     X = check_array(
#    1107         X,
#    1108         accept_sparse=accept_sparse,
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
# --> 879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    2068
#    2069     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070         return np.asarray(self._values, dtype=dtype)
#    2071
#    2072     def __array_wrap__(
#
# ValueError: could not convert string to float: 'diesel'

# %%
predictions = model.predict(x_test)
mse         = mean_squared_error(y_test,predictions)
r2          = r2_score(y_test,predictions)
rmse        = np.sqrt(mse)
print('R2 score                :',r2)
print('Root Mean Squared Error :',rmse)
print('mean squared error      :',mse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_36739/1894392877.py in <module>
# ----> 1 predictions=model.predict(x_test)
#       2 mse=mean_squared_error(y_test,predictions)
#       3 r2 = r2_score(y_test,predictions)
#       4 rmse=np.sqrt(mse)
#       5 print('R2 score                :',r2)
#
# ~/.local/lib/python3.10/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# ~/.local/lib/python3.10/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# --> 337         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     339
#
# ~/.local/lib/python3.10/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
# --> 879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    2068
#    2069     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070         return np.asarray(self._values, dtype=dtype)
#    2071
#    2072     def __array_wrap__(
#
# ValueError: could not convert string to float: 'gas'

# %%
df.iloc[0]
# Out:
# Brand                alfa-romeo
# Model                    giulia
# fueltype                    gas
# aspiration                  std
# doornumber                  two
# carbody             convertible
# drivewheel                  rwd
# enginelocation            front
# enginetype                 dohc
# fuelsystem                 mpfi
# symboling                     3
# wheelbase                  88.6
# carlength                 168.8
# carwidth                   64.1
# carheight                  48.8
# curbweight               2548.0
# cylindernumber                4
# enginesize                  130
# boreratio                  3.47
# stroke                     2.68
# compressionratio            9.0
# horsepower                111.0
# peakrpm                  5000.0
# citympg                    21.0
# highwaympg                 27.0
# price                     13495
# Name: 0, dtype: object

# %%
#Predicting Car Price for a new data
import pandas as pd

#New data
new_car = [['alfa-romero','giulia', 'gas', 'std', 'two', 'convertible', 'rwd', 'front', 'dohc','mpfi',
                 3,88.6, 168.8, 64.1, 48.8, 2548, 4, 130, 3.47, 2.68, 9.0, 111, 5000, 21, 27]]

# Define the column names based on the original dataset's columns
new_car_col = ['Brand', 'Model', 'fueltype', 'aspiration', 'doornumber', 'carbody',
       'drivewheel', 'enginelocation', 'enginetype', 'fuelsystem', 'symboling',
       'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
       'cylindernumber', 'enginesize', 'boreratio', 'stroke',
       'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']

# Create a DataFrame with the data and column names
car_df = pd.DataFrame(new_car, columns=new_car_col)

# Drop the 'CarName' column as it's not needed for prediction
car_df.drop(columns=['Brand'], inplace=True)

# Encode categorical columns (one-hot encoding)
car_ohe = pd.get_dummies(car_df, drop_first=True)

#"Aligning and Preparing New Car Data for Prediction with Trained Model"

car_ohe = car_ohe.reindex(columns=x_train.columns, fill_value=0)

# Predict the car price using the model
predicted_price = model.predict(car_ohe)

# Ensure the predicted price is positive
predicted_price = max(0, round(predicted_price[0],3))  # Ensure the price is not negative

print('Predicted_price:', predicted_price)
# Out:
# Predicted_price: 1561.803
